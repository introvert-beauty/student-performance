# %% [markdown]
# Importing some dependencies for required

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# DATA COLLECTION

# %%
df=pd.read_csv(r"D:\RESUME ML PROJECTS\student_performance\notebooks\Student_performance_data _.csv")

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.shape
# Out:
# (2392, 15)

# %%
# check missing values
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
# check duplicated
df.duplicated().sum()
# Out:
# 0

# %%
# check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
# check statistics of the data
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
# visulization of the data
df.head(2)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0

# %%
# drop some cols
df=df.drop(columns=["StudentID"])

# %%
df.head(2)
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
#
#         GPA  GradeClass
# 0  2.929196         2.0
# 1  3.042915         1.0

# %%
print("gender unique values are,: ", end=" ")
print(df["Gender"].unique())

print("Ethnicity unique values are: ",end="")
print(df["Ethnicity"].unique())

print("ParentalEducation unique values are: ",end="")
print(df["ParentalEducation"].unique())

print("Music unique values are: ",end="")
print(df["Music"].unique())

print("Tutoring unique values are: ",end="")
print(df["Tutoring"].unique())

print("Tutoring unique values are: ",end="")
print(df["Tutoring"].unique())
# Out:
# gender unique values are,:  [1 0]
# Ethnicity unique values are: [0 2 1 3]
# ParentalEducation unique values are: [2 1 3 4 0]
# Music unique values are: [1 0]
# Tutoring unique values are: [1 0]
# Tutoring unique values are: [1 0]

# %%
# Assuming df is your DataFrame and it has a 'Gender' column
sns.countplot(x="Gender", data=df)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
fig,axs=plt.subplots(1,4,figsize=(5,5))
plt.subplot(121)
sns.countplot(data=df,x="Gender")
plt.show()

plt.subplot(122)
sns.countplot(data=df,x="Ethnicity")
plt.show()

# %%
df.to_csv("cleanedddata.csv")

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="StudyTimeWeekly", y="GPA", hue="Gender", data=df)
plt.title("Score vs. Weekly Study Time")
plt.xlabel("Weekly Study Time (Hours)")
plt.ylabel("Score")
plt.show()
